# %%
#Task 1.1
import sqlite3

conn = sqlite3.connect('TESTDATABASE.db')
conn.execute('''CREATE TABLE Student(
    StudentID INTEGER PRIMARY KEY,
    GivenName TEXT,
    FamilyName TEXT,
    ClassName TEXT,
    FOREIGN KEY (ClassName) REFERENCES Class(ClassName)
)''')
conn.execute('''CREATE TABLE Test(
    TestID TEXT PRIMARY KEY,
    MaxMarks INTEGER
)''')
conn.execute('''CREATE TABLE Class(
    ClassName TEXT PRIMARY KEY,
    YearGroup INTEGER
)''')
conn.execute('''CREATE TABLE Student_Test(
    StudentTestID INTEGER PRIMARY KEY,
    StudentID INTEGER,
    TestID TEXT,
    Mark INTEGER,
    DateTest TEXT,
    FOREIGN KEY (StudentID) REFERENCES Student(StudentID),
    FOREIGN KEY (TestID) REFERENCES Test(TestID)
)''')

conn.commit()
conn.close()

# %%
#Task 1.2
conn = sqlite3.connect('TESTDATABASE.db')

conn.execute('INSERT INTO Class VALUES ("CS3", 12)')
conn.execute('INSERT INTO Test VALUES ("PG1", 100)')
conn.execute('INSERT INTO Student VALUES (102, "Mary", "Lim", "CS3")')
conn.execute('INSERT INTO Student_Test VALUES (123, 102, "PG1", 85, "01-02-2023")')

conn.commit()
conn.close()
